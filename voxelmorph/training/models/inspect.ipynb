# %%
import voxelmorph as vxm
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import CustomObjectScope

from voxelmorph.tf.layers import VecInt, RescaleTransform, SpatialTransformer


custom_objs = {
    "VxmDense": vxm.networks.VxmDense,
    "VecInt": VecInt,
    "RescaleTransform": RescaleTransform,
    "SpatialTransformer": SpatialTransformer
}

with CustomObjectScope(custom_objs):
    model = load_model('vxm2d_model_tf.h5', compile=False)

model.summary()
for layer in model.layers:
    print(f"{layer.name:30s}  {layer.__class__.__name__:20s}  output_shape={layer.output_shape}")
# Out:
# Model: "vxm_dense"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  vxm_dense_source_input (In  [(None, 192, 224, 1)]        0         []
#  putLayer)
#
#  vxm_dense_target_input (In  [(None, 192, 224, 1)]        0         []
#  putLayer)
#
#  vxm_dense_unet_input_conca  (None, 192, 224, 2)          0         ['vxm_dense_source_input[0][0]
#  t (Concatenate)                                                    ',
#                                                                      'vxm_dense_target_input[0][0]
#                                                                     ']
#
#  vxm_dense_unet_enc_conv_0_  (None, 192, 224, 32)         608       ['vxm_dense_unet_input_concat[
#  0 (Conv2D)                                                         0][0]']
#
# ...
